# %%
import pandas as pd

# %%
internacional = pd.read_excel('/Users/matias/Library/CloudStorage/GoogleDrive-mvilla@buenavistacapital.com/.shortcut-targets-by-id/1Lbjcks5sDTC17AftNR6mDxW8bwAA7EaA/BVC/Matias V/Ranking Fondos/Data.xlsx', sheet_name='Internacional fijo')
internacional

# %%
nacional = pd.read_excel('/Users/matias/Library/CloudStorage/GoogleDrive-mvilla@buenavistacapital.com/.shortcut-targets-by-id/1Lbjcks5sDTC17AftNR6mDxW8bwAA7EaA/BVC/Matias V/Ranking Fondos/Data.xlsx', sheet_name='Nacional fijo')
nacional
# Out:
#           Dates  AACCHIA CI Equity  CCHIACB CI Equity  CELFFIB CI EQUITY  \
# 0    2007-01-01                NaN                NaN         33239.7839
# 1    2007-01-02                NaN                NaN         33250.4300
# 2    2007-01-03                NaN                NaN         33408.7278
# 3    2007-01-04                NaN                NaN         33391.5505
# 4    2007-01-05                NaN                NaN         33342.5164
# ...         ...                ...                ...                ...
# 4897        NaT                NaN                NaN                NaN
# 4898        NaT                NaN                NaN                NaN
# 4899        NaT                NaN                NaN                NaN
# 4900        NaT                NaN                NaN                NaN
# 4901        NaT                NaN                NaN                NaN
#
#       CFIMPIO CI EQUITY  CFIQAC CI EQUITY  ECH US EQUITY  FALCTNV CI EQUITY  \
# 0             2743.7330               NaN            NaN                NaN
# 1             2739.2791               NaN            NaN                NaN
# 2             2751.5267               NaN            NaN                NaN
# 3             2761.7548               NaN            NaN                NaN
# 4             2777.6091               NaN            NaN                NaN
# ...                 ...               ...            ...                ...
# 4897                NaN               NaN            NaN                NaN
# 4898                NaN               NaN            NaN                NaN
# 4899                NaN               NaN            NaN                NaN
# 4900                NaN               NaN            NaN                NaN
# 4901                NaN               NaN            NaN                NaN
#
#       MBIARANV CI EQUITY  TCHIEQB CI EQUITY  ...  MODUECH CI EQUITY  \
# 0             24952.7896                NaN  ...                NaN
# 1             24965.0939                NaN  ...                NaN
# 2             24926.1817                NaN  ...                NaN
# 3             25060.9742                NaN  ...                NaN
# 4             24952.7931                NaN  ...                NaN
# ...                  ...                ...  ...                ...
# 4897                 NaN                NaN  ...                NaN
# 4898                 NaN                NaN  ...                NaN
# 4899                 NaN                NaN  ...                NaN
# 4900                 NaN                NaN  ...                NaN
# 4901                 NaN                NaN  ...                NaN
#
#       MRCLP CI EQUITY  IPSA Index  FIQRLSA CI Equity  FCFIANV CI Equity  \
# 0                 NaN     2693.36                NaN                NaN
# 1                 NaN     2689.19                NaN                NaN
# 2                 NaN     2725.60                NaN                NaN
# 3                 NaN     2738.99                NaN                NaN
# 4                 NaN     2723.48                NaN                NaN
# ...               ...         ...                ...                ...
# 4897              NaN         NaN           16214.32          1765.3515
# 4898              NaN         NaN           16206.27          1763.8071
# 4899              NaN         NaN           16212.61          1763.9592
# 4900              NaN         NaN           16217.79          1764.5898
# 4901              NaN         NaN           16217.79          1764.5898
#
#       IMTDECI CI Equity  MODECHD CI Equity  DEUCORP CI Equity  \
# 0                   NaN                NaN                NaN
# 1                   NaN                NaN                NaN
# 2                   NaN                NaN                NaN
# 3                   NaN                NaN                NaN
# 4                   NaN                NaN                NaN
# ...                 ...                ...                ...
# 4897          1752.3660          1532.2225         49857.8898
# 4898          1750.5294          1531.0770         49812.6349
# 4899          1751.7193          1531.2919         49828.3057
# 4900          1752.3001          1531.6712         49842.6832
# 4901          1752.3001          1531.6712         49842.6832
#
#       CFIETFCC CC Equity  MBIDTANV CI Equity
# 0                    NaN                 NaN
# 1                    NaN                 NaN
# 2                    NaN                 NaN
# 3                    NaN                 NaN
# 4                    NaN                 NaN
# ...                  ...                 ...
# 4897            1517.596          17244.4447
# 4898            1517.081          17229.4921
# 4899            1517.699          17240.0191
# 4900            1518.111          17245.4492
# 4901            1517.596          17245.4492
#
# [4902 rows x 29 columns]

# %%
df_final = pd.merge(internacional, nacional, how = 'left', on = 'Dates')
df_final = df_final.dropna(axis=1, how='all')
df_final
# Out:
#           Dates  0JKT LN Equity  AAXJ US Equity  ABCHNSA LX EQUITY  \
# 0    2007-01-01             NaN             NaN                NaN
# 1    2007-01-02             NaN             NaN                NaN
# 2    2007-01-03             NaN             NaN                NaN
# 3    2007-01-04             NaN             NaN                NaN
# 4    2007-01-05             NaN             NaN                NaN
# ...         ...             ...             ...                ...
# 4886 2025-09-23        33.03644        123.6590             131.11
# 4887 2025-09-24        33.03644        123.2522             132.59
# 4888 2025-09-25        33.03644        122.8318             133.13
# 4889 2025-09-26        33.03644        122.1266             131.31
# 4890 2025-09-29        33.03644        123.3200             131.31
#
#       BGFPABA LN EQUITY  CPXJ LN EQUITY  CAFINIV LX EQUITY  FFASAIU LX EQUITY  \
# 0               4.13102             NaN             124.47                NaN
# 1               4.17635             NaN             125.69                NaN
# 2               4.11882             NaN             126.26                NaN
# 3               4.03831             NaN             125.45                NaN
# 4               4.05409             NaN             124.76                NaN
# ...                 ...             ...                ...                ...
# 4886           20.03812          218.43             501.81              16.27
# 4887           19.98974          215.84             499.77              16.18
# 4888           19.88845          214.68             496.91              16.11
# 4889           19.76205          215.89             492.63              16.07
# 4890           19.91817          218.27             492.63              16.09
#
#       FFEMASI LX EQUITY  FIASCIU LX EQUITY  ...  MODUECH CI EQUITY  \
# 0                   NaN                NaN  ...                NaN
# 1                   NaN                NaN  ...                NaN
# 2                   NaN                NaN  ...                NaN
# 3                   NaN                NaN  ...                NaN
# 4                   NaN                NaN  ...                NaN
# ...                 ...                ...  ...                ...
# 4886              28.47              23.56  ...          1898.7715
# 4887              28.50              23.52  ...          1898.0130
# 4888              28.29              23.42  ...          1898.0914
# 4889              27.95              23.31  ...          1899.4228
# 4890              28.37              23.43  ...          1899.7732
#
#       MRCLP CI EQUITY  IPSA Index  FIQRLSA CI Equity  FCFIANV CI Equity  \
# 0                 NaN     2693.36                NaN                NaN
# 1                 NaN     2689.19                NaN                NaN
# 2                 NaN     2725.60                NaN                NaN
# 3                 NaN     2738.99                NaN                NaN
# 4                 NaN     2723.48                NaN                NaN
# ...               ...         ...                ...                ...
# 4886        20871.156     9146.80           16116.28          1757.6365
# 4887        20867.343     9114.79           16111.24          1756.6948
# 4888        20882.300     9040.46           16110.98          1756.5987
# 4889        20871.407     9023.05           16140.02          1758.3600
# 4890        20898.640     8996.57           16151.75          1760.4616
#
#       IMTDECI CI Equity  MODECHD CI Equity  DEUCORP CI Equity  \
# 0                   NaN                NaN                NaN
# 1                   NaN                NaN                NaN
# 2                   NaN                NaN                NaN
# 3                   NaN                NaN                NaN
# 4                   NaN                NaN                NaN
# ...                 ...                ...                ...
# 4886          1745.0538          1527.0008         49625.6107
# 4887          1744.3139          1526.3732         49595.2662
# 4888          1743.8363          1526.4185         49587.1809
# 4889          1745.4285          1527.4716         49678.9190
# 4890          1747.5861          1528.8897         49726.2951
#
#       CFIETFCC CC Equity  MBIDTANV CI Equity
# 0                    NaN                 NaN
# 1                    NaN                 NaN
# 2                    NaN                 NaN
# 3                    NaN                 NaN
# 4                    NaN                 NaN
# ...                  ...                 ...
# 4886            1513.372          17163.2542
# 4887            1511.723          17159.1192
# 4888            1512.959          17151.8829
# 4889            1511.723          17169.2268
# 4890            1513.268          17183.7091
#
# [4891 rows x 604 columns]

# %%
df_final.to_csv('/Users/matias/Desktop/Proyectos/ranking-fondos/data/funds_prices.csv')

# %%
diccionario = pd.read_excel('dict_temp_full_portfolio.xlsx')
diccionario.to_csv('/Users/matias/Desktop/Proyectos/ranking-fondos/data/funds_dictionary.csv')
